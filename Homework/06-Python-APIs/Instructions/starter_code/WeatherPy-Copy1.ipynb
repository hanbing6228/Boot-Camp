# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# import dependencies
import random # random to generate random latitude and longitudes
import pandas as pd # pandas library
import time 
import seaborn as sns # seaborn library to set the aesthetics for the graphs
import matplotlib.pyplot as plt # for creating/plotting graphs
import numpy as np
from datetime import datetime
import openweathermapy as ow
import csv

# %% [markdown]
# ## Generate Cities List

# %%
# citypy library - to Look up for city names with geo-coordinates
from citipy import citipy 
cities = []

while len(cities)<600:
    x = (random.choice(range(-90,90))) # randomly generate numbers in range -90 & 90 for latitude
    y = (random.choice(range(-180,180))) # randomly generagte numbers in range -180 & 180 for longitude
    city = citipy.nearest_city(x,y).city_name # look up city to match the lat & long randomly generated
    if city not in cities:
        cities.append(city)
    len(cities)

len(cities)
cities
# Out:
# ['ossora',
#  'atuona',
#  'carnarvon',
#  'tsihombe',
#  'vao',
#  'durban',
#  'punta arenas',
#  'hilo',
#  'illoqqortoormiut',
#  'ushuaia',
#  'mahebourg',
#  'castro',
#  'busselton',
#  'grindavik',
#  'meulaboh',
#  'taolanaro',
#  'praia da vitoria',
#  'lebu',
#  'parkes',
#  'dikson',
#  'jabinyanah',
#  'ahipara',
#  'port alfred',
#  'belushya guba',
#  'mar del plata',
#  'cayenne',
#  'soyo',
#  'jamestown',
#  'sturgeon bay',
#  'crixas',
#  'butaritari',
#  'harstad',
#  'puerto ayora',
#  'attawapiskat',
#  'ketchikan',
#  'sorong',
#  'tumannyy',
#  'moyale',
#  'new norfolk',
#  'albany',
#  'peterhead',
#  'coruripe',
#  'laguna',
#  'urengoy',
#  'nikolskoye',
#  'villa constitucion',
#  'iqaluit',
#  'eyl',
#  'mataura',
#  'dudinka',
#  'east london',
#  'saskylakh',
#  'comodoro rivadavia',
#  'saldanha',
#  'vostok',
#  'sakakah',
#  'saint george',
#  'tuktoyaktuk',
#  'hobart',
#  'glamoc',
#  'todos santos',
#  'pisco',
#  'tuatapere',
#  'jaguarao',
#  'durango',
#  'rikitea',
#  'barrow',
#  'hithadhoo',
#  'duku',
#  'port elizabeth',
#  'kaitangata',
#  'tilichiki',
#  'sarangani',
#  'saint-philippe',
#  'tynda',
#  'tasiilaq',
#  'avarua',
#  'srednekolymsk',
#  'kudahuvadhoo',
#  'bluff',
#  'haines junction',
#  'marawi',
#  'ambon',
#  'paraiso',
#  'isagarh',
#  'kamenskoye',
#  'cape town',
#  'sumbawa',
#  'sisimiut',
#  'vaini',
#  'luderitz',
#  'deputatskiy',
#  'airai',
#  'klaksvik',
#  'salalah',
#  'caconda',
#  'port hardy',
#  'nuqui',
#  'bluefields',
#  'ribeira grande',
#  'oistins',
#  'ancud',
#  'quimper',
#  'yarensk',
#  'potsdam',
#  'shubarkuduk',
#  'nhulunbuy',
#  'rudnogorsk',
#  'chagda',
#  'tongren',
#  'tiksi',
#  'staden',
#  'irtyshskiy',
#  'sao jose da coroa grande',
#  'huilong',
#  'inhambane',
#  'barentsburg',
#  'myaundzha',
#  'muravlenko',
#  'nizhneyansk',
#  'grand river south east',
#  'parrita',
#  'sorland',
#  'pevek',
#  'wewak',
#  'samarai',
#  'severo-kurilsk',
#  'yellowknife',
#  'richards bay',
#  'margate',
#  'henties bay',
#  'atambua',
#  'qaanaaq',
#  'bredasdorp',
#  'kangaba',
#  'ponta delgada',
#  'hermanus',
#  'victoria',
#  'amderma',
#  'bethel',
#  'isangel',
#  'karauzyak',
#  'jinchang',
#  'middelburg',
#  'kapaa',
#  'yar-sale',
#  'derzhavinsk',
#  'seymour',
#  'cidreira',
#  'vanavara',
#  'arraial do cabo',
#  'sfantu gheorghe',
#  'santa rosa',
#  'norman wells',
#  'rockland',
#  'ponta do sol',
#  'torres',
#  'alamor',
#  'vigrestad',
#  'torbay',
#  'longyearbyen',
#  'barabai',
#  'sitka',
#  'santo augusto',
#  'upernavik',
#  'geraldton',
#  'dali',
#  'bonthe',
#  'saint-pierre',
#  'esperance',
#  'san rafael',
#  'muros',
#  'cap malheureux',
#  'thompson',
#  'yumen',
#  'rexburg',
#  'bloemfontein',
#  'yerofey pavlovich',
#  'preobrazheniye',
#  'rocha',
#  'khatanga',
#  'talnakh',
#  'cherskiy',
#  'seydi',
#  'cabo san lucas',
#  'venado tuerto',
#  'chokurdakh',
#  'pacific grove',
#  'kodiak',
#  'cervo',
#  'nishihara',
#  'souillac',
#  'masvingo',
#  'yakeshi',
#  'caravelas',
#  'karasuk',
#  'north bend',
#  'yerbogachen',
#  'kananga',
#  'faanui',
#  'adrar',
#  'linxia',
#  'muli',
#  'hwange',
#  'itoman',
#  'tura',
#  'los andes',
#  'berlevag',
#  'belmonte',
#  'alexandria',
#  'padang',
#  'dumabato',
#  'lufilufi',
#  'maceio',
#  'lata',
#  'cockburn town',
#  'cabinda',
#  'pangnirtung',
#  'malwan',
#  'havelock',
#  'el alto',
#  'champerico',
#  'dunedin',
#  'zirandaro',
#  'terenos',
#  'tahta',
#  'arman',
#  'codrington',
#  'coquimbo',
#  'aginskoye',
#  'ulundi',
#  'nichinan',
#  'kuusamo',
#  'calgary',
#  'clyde river',
#  'lompoc',
#  'general roca',
#  'marfino',
#  'umm lajj',
#  'batagay',
#  'senneterre',
#  'puerto castilla',
#  'muzquiz',
#  'krasnoselkup',
#  'umzimvubu',
#  'santa eulalia del rio',
#  'kormilovka',
#  'mount gambier',
#  'ulladulla',
#  'sola',
#  'sabzevar',
#  'port blair',
#  'vyshestebliyevskaya',
#  'akyab',
#  'olafsvik',
#  'syracuse',
#  'juba',
#  'sobolevo',
#  'praya',
#  'mandalgovi',
#  'nizwa',
#  'khash',
#  'makakilo city',
#  'marrakesh',
#  'marcona',
#  'mergui',
#  'magway',
#  'baturaja',
#  'storforshei',
#  'biak',
#  'khorion',
#  'flinders',
#  'samusu',
#  'yulara',
#  'vestmannaeyjar',
#  'tsiroanomandidy',
#  'punto fijo',
#  'svetlaya',
#  'mehamn',
#  'kamina',
#  'guerrero negro',
#  'kirakira',
#  'chiredzi',
#  'botshabelo',
#  'dakar',
#  'elko',
#  'aguimes',
#  'dwarka',
#  'alto araguaia',
#  'port macquarie',
#  'tucuman',
#  'katherine',
#  'nanortalik',
#  'nosy varika',
#  'severo-yeniseyskiy',
#  'road town',
#  'padampur',
#  'rawannawi',
#  'ust-bolsheretsk',
#  'sibolga',
#  'beringovskiy',
#  'dzheguta',
#  'los llanos de aridane',
#  'katsuura',
#  'coos bay',
#  'mys shmidta',
#  'vaitupu',
#  'matelica',
#  'joao pinheiro',
#  'banamba',
#  'bambous virieux',
#  'san patricio',
#  'alice springs',
#  'atasu',
#  'fortuna',
#  'maxixe',
#  'kargil',
#  'provideniya',
#  'blackfoot',
#  'dongsheng',
#  'kirovsk',
#  'sulina',
#  'madimba',
#  'banikoara',
#  'riyadh',
#  'takob',
#  'namibe',
#  'ati',
#  'tuburan',
#  'nahrin',
#  'tamandare',
#  'chicama',
#  'mankato',
#  'saint-leu',
#  'balkhash',
#  'sydney',
#  'pimentel',
#  'sinnar',
#  'itarema',
#  'otaru',
#  'eenhana',
#  'marica',
#  'riaba',
#  'the pas',
#  'altay',
#  'gravdal',
#  'port-de-bouc',
#  'rawson',
#  'lavrentiya',
#  'kavieng',
#  'ilulissat',
#  'halalo',
#  'hasaki',
#  'uusikaupunki',
#  'hervey bay',
#  'vila velha',
#  'sentyabrskiy',
#  'merauke',
#  'miranda',
#  'nantucket',
#  'fairbanks',
#  'lensk',
#  'teguldet',
#  'lang son',
#  'vila franca do campo',
#  'liverpool',
#  'quatre cocos',
#  'mitsamiouli',
#  'chuy',
#  'davidson',
#  'mareeba',
#  'belaya glina',
#  'yialos',
#  'arroio grande',
#  'puerto suarez',
#  'gornopravdinsk',
#  'fort saint john',
#  'mount isa',
#  'husavik',
#  'tigzirt',
#  'port lincoln',
#  'khonuu',
#  'chapais',
#  'kasama',
#  'murgab',
#  'delvine',
#  'mendahara',
#  'dalmau',
#  'hambantota',
#  'bereda',
#  'ambilobe',
#  'weiser',
#  'muscat',
#  'lasa',
#  'moindou',
#  'touros',
#  'bengkulu',
#  'kommunar',
#  'san pedro',
#  'vardo',
#  'broome',
#  'fayaoue',
#  'georgetown',
#  'egvekinot',
#  'valdivia',
#  'grand centre',
#  'san quintin',
#  'saleaula',
#  'siocon',
#  'amapa',
#  'thinadhoo',
#  'lichinga',
#  'nioaque',
#  'hofn',
#  'labuhan',
#  'tazovskiy',
#  'wahran',
#  'homer',
#  'asau',
#  'poum',
#  'nanning',
#  'ozernovskiy',
#  'nnewi',
#  'adre',
#  'diego de almagro',
#  'faya',
#  'porto novo',
#  'mandera',
#  'lolua',
#  'green river',
#  'amudat',
#  'ostrovnoy',
#  'mazagao',
#  'westport',
#  'porto velho',
#  'sioux lookout',
#  'misratah',
#  'irbit',
#  'labutta',
#  'kontagora',
#  'cabedelo',
#  'buraydah',
#  'houma',
#  'thunder bay',
#  'bowmore',
#  'sindor',
#  'sao filipe',
#  'bekhtery',
#  'ambulu',
#  'panama city',
#  'humboldt',
#  'plettenberg bay',
#  'imphal',
#  'naze',
#  'new ulm',
#  'one hundred mile house',
#  'fram',
#  'hovd',
#  'gat',
#  'umtata',
#  'tommot',
#  'kostino',
#  'erenhot',
#  'saint-augustin',
#  'marzuq',
#  'warrnambool',
#  'lubango',
#  'luena',
#  'gazanjyk',
#  'verona',
#  'karratha',
#  'gobabis',
#  'samalaeulu',
#  'esna',
#  'karaul',
#  'coihaique',
#  'kutum',
#  'lorengau',
#  'port-cartier',
#  'kiama',
#  'nanaimo',
#  'waingapu',
#  'orsha',
#  'bako',
#  'shelburne',
#  'nome',
#  'ucluelet',
#  'bundaberg',
#  'adwa',
#  'whyalla',
#  'bairiki',
#  'kamenka',
#  'kawalu',
#  'nara',
#  'cotonou',
#  'paluan',
#  'korla',
#  'bilma',
#  'tanout',
#  'esmeraldas',
#  'iaciara',
#  'mahuva',
#  'batagay-alyta',
#  'birecik',
#  'sao joao da barra',
#  'fare',
#  'hualmay',
#  'jacareacanga',
#  'aksaray',
#  'darnah',
#  'abha',
#  'yinchuan',
#  'avera',
#  'vangaindrano',
#  'vitim',
#  'tual',
#  'sabang',
#  'lugazi',
#  'shimoda',
#  'sheridan',
#  'villa maria',
#  'taoudenni',
#  'mweka',
#  'mouila',
#  'pandan',
#  'anadyr',
#  'volokolamsk',
#  'ternate',
#  'huanren',
#  'poronaysk',
#  'bathsheba',
#  'pesaro',
#  'aranda de duero',
#  'komsomolskiy',
#  'leningradskiy',
#  'sigli',
#  'dingle',
#  'paradwip',
#  'panzhihua',
#  'ixtapa',
#  'tolbazy',
#  'arlit',
#  'alofi',
#  'tongchuan',
#  'dubai',
#  'cuamba',
#  'kahului',
#  'fallon',
#  'sechura',
#  'mosquera',
#  'kingori',
#  'lulea',
#  'kupang',
#  'iquique',
#  'balimo',
#  'victor harbor',
#  'luganville',
#  'coolum beach',
#  'namatanai',
#  'sogdiondon',
#  'diamantino',
#  'toritama',
#  'sept-iles',
#  'yirol',
#  'zonguldak',
#  'yambio',
#  'serenje',
#  'altamont',
#  'manokwari',
#  'navoi',
#  'sedelnikovo',
#  'gibara',
#  'hamilton',
#  'salme',
#  'bacuit',
#  'ust-ilimsk',
#  'mazabuka',
#  'abu samrah',
#  'pahrump',
#  'ugoofaaru',
#  'voznesenye',
#  'xining',
#  'clearwater',
#  'easton',
#  'sorvag',
#  'port keats',
#  'lagoa',
#  'kurumkan',
#  'turtas',
#  'othonoi',
#  'osoyoos',
#  'san cristobal',
#  'zhigansk',
#  'panaba',
#  'sibu',
#  'bogo',
#  'sinnamary',
#  'kavaratti',
#  'constitucion',
#  'santiago del estero']

# %%
# import API Key from config file
from api_keys import api_key
# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country", "Date", "Max Temp", "Wind Speed", "Lat", "Lng", "Humidity"])
WeatherPy_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Max Temp, Wind Speed, Lat, Lng, Humidity]
# Index: []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") # remove space in city name so the URL retrieved is not broken.
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{ow.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = ow.get_current(city, **settings)
        WeatherPy_df.at["City", city_stats["name"]]
        WeatherPy_df.at[index, "Cloudiness", city_stats("clouds.all")]
        WeatherPy_df.at[index, "Country", city_stats("sys.country")]
        WeatherPy_df.at[index, "Date", city_stats("dt")]
        WeatherPy_df.at[index, "Max Temp", city_stats("main.temp_max")]
        WeatherPy_df.at[index, "Wind Speed", city_stats("wind.speed")]
        WeatherPy_df.at[index, "Lat", city_stats("coord.lat")]
        WeatherPy_df.at[index, "Lng", city_stats("coord.lon")]
        WeatherPy_df.at[index, "Humidity", city_stats("main.humidity")]
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: # loop to limit 50 API calls per minute. The OpenWeatherMap API limit is 60 calls/min
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60)
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | ossora
# http://api.openweathermap.org/data/2.5/weather?q=ossora&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ossora'
# Processing Record 2 of Set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Atuona'
# Processing Record 3 of Set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Carnarvon'
# Processing Record 4 of Set 0 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 5 of Set 0 | vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vao'
# Processing Record 6 of Set 0 | durban
# http://api.openweathermap.org/data/2.5/weather?q=durban&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Durban'
# Processing Record 7 of Set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Punta Arenas'
# Processing Record 8 of Set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hilo'
# Processing Record 9 of Set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 10 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ushuaia'
# Processing Record 11 of Set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mahebourg'
# Processing Record 12 of Set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Castro'
# Processing Record 13 of Set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Busselton'
# Processing Record 14 of Set 0 | grindavik
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Grindavik'
# Processing Record 15 of Set 0 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Meulaboh'
# Processing Record 16 of Set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 17 of Set 0 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?q=praia%20da%20vitoria&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Praia da Vitoria'
# Processing Record 18 of Set 0 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lebu'
# Processing Record 19 of Set 0 | parkes
# http://api.openweathermap.org/data/2.5/weather?q=parkes&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Parkes'
# Processing Record 20 of Set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dikson'
# Processing Record 21 of Set 0 | jabinyanah
# http://api.openweathermap.org/data/2.5/weather?q=jabinyanah&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Jabinyanah'
# Processing Record 22 of Set 0 | ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ahipara'
# Processing Record 23 of Set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port%20alfred&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Port Alfred'
# Processing Record 24 of Set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya%20guba&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 25 of Set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar%20del%20plata&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mar del Plata'
# Processing Record 26 of Set 0 | cayenne
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cayenne'
# Processing Record 27 of Set 0 | soyo
# http://api.openweathermap.org/data/2.5/weather?q=soyo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Soyo'
# Processing Record 28 of Set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Jamestown'
# Processing Record 29 of Set 0 | sturgeon bay
# http://api.openweathermap.org/data/2.5/weather?q=sturgeon%20bay&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sturgeon Bay'
# Processing Record 30 of Set 0 | crixas
# http://api.openweathermap.org/data/2.5/weather?q=crixas&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Crixas'
# Processing Record 31 of Set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Butaritari'
# Processing Record 32 of Set 0 | harstad
# http://api.openweathermap.org/data/2.5/weather?q=harstad&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Harstad'
# Processing Record 33 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Puerto Ayora'
# Processing Record 34 of Set 0 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 35 of Set 0 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?q=ketchikan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ketchikan'
# Processing Record 36 of Set 0 | sorong
# http://api.openweathermap.org/data/2.5/weather?q=sorong&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sorong'
# Processing Record 37 of Set 0 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 38 of Set 0 | moyale
# http://api.openweathermap.org/data/2.5/weather?q=moyale&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Moyale'
# Processing Record 39 of Set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new%20norfolk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'New Norfolk'
# Processing Record 40 of Set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Albany'
# Processing Record 41 of Set 0 | peterhead
# http://api.openweathermap.org/data/2.5/weather?q=peterhead&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Peterhead'
# Processing Record 42 of Set 0 | coruripe
# http://api.openweathermap.org/data/2.5/weather?q=coruripe&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Coruripe'
# Processing Record 43 of Set 0 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Laguna'
# Processing Record 44 of Set 0 | urengoy
# http://api.openweathermap.org/data/2.5/weather?q=urengoy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Urengoy'
# Processing Record 45 of Set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Nikolskoye'
# Processing Record 46 of Set 0 | villa constitucion
# http://api.openweathermap.org/data/2.5/weather?q=villa%20constitucion&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Villa Constitucion'
# Processing Record 47 of Set 0 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Iqaluit'
# Processing Record 48 of Set 0 | eyl
# http://api.openweathermap.org/data/2.5/weather?q=eyl&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Eyl'
# Processing Record 49 of Set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mataura'
# Processing Record 50 of Set 0 | dudinka
# http://api.openweathermap.org/data/2.5/weather?q=dudinka&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dudinka'
# Processing Record 1 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'East London'
# Processing Record 2 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Saskylakh'
# Processing Record 3 of Set 1 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=comodoro%20rivadavia&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Comodoro Rivadavia'
# Processing Record 4 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Saldanha'
# Processing Record 5 of Set 1 | vostok
# http://api.openweathermap.org/data/2.5/weather?q=vostok&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vostok'
# Processing Record 6 of Set 1 | sakakah
# http://api.openweathermap.org/data/2.5/weather?q=sakakah&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 7 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint%20george&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Saint George'
# Processing Record 8 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tuktoyaktuk'
# Processing Record 9 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hobart'
# Processing Record 10 of Set 1 | glamoc
# http://api.openweathermap.org/data/2.5/weather?q=glamoc&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Glamoc'
# Processing Record 11 of Set 1 | todos santos
# http://api.openweathermap.org/data/2.5/weather?q=todos%20santos&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Todos Santos'
# Processing Record 12 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pisco'
# Processing Record 13 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tuatapere'
# Processing Record 14 of Set 1 | jaguarao
# http://api.openweathermap.org/data/2.5/weather?q=jaguarao&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Jaguarao'
# Processing Record 15 of Set 1 | durango
# http://api.openweathermap.org/data/2.5/weather?q=durango&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Durango'
# Processing Record 16 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Rikitea'
# Processing Record 17 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Barrow'
# Processing Record 18 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hithadhoo'
# Processing Record 19 of Set 1 | duku
# http://api.openweathermap.org/data/2.5/weather?q=duku&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Duku'
# Processing Record 20 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port%20elizabeth&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Port Elizabeth'
# Processing Record 21 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kaitangata'
# Processing Record 22 of Set 1 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tilichiki'
# Processing Record 23 of Set 1 | sarangani
# http://api.openweathermap.org/data/2.5/weather?q=sarangani&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sarangani'
# Processing Record 24 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Saint-Philippe'
# Processing Record 25 of Set 1 | tynda
# http://api.openweathermap.org/data/2.5/weather?q=tynda&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tynda'
# Processing Record 26 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tasiilaq'
# Processing Record 27 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Avarua'
# Processing Record 28 of Set 1 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Srednekolymsk'
# Processing Record 29 of Set 1 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kudahuvadhoo'
# Processing Record 30 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bluff'
# Processing Record 31 of Set 1 | haines junction
# http://api.openweathermap.org/data/2.5/weather?q=haines%20junction&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Haines Junction'
# Processing Record 32 of Set 1 | marawi
# http://api.openweathermap.org/data/2.5/weather?q=marawi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Marawi'
# Processing Record 33 of Set 1 | ambon
# http://api.openweathermap.org/data/2.5/weather?q=ambon&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ambon'
# Processing Record 34 of Set 1 | paraiso
# http://api.openweathermap.org/data/2.5/weather?q=paraiso&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Paraiso'
# Processing Record 35 of Set 1 | isagarh
# http://api.openweathermap.org/data/2.5/weather?q=isagarh&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Isagarh'
# Processing Record 36 of Set 1 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 37 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape%20town&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cape Town'
# Processing Record 38 of Set 1 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?q=sumbawa&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 39 of Set 1 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?q=sisimiut&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sisimiut'
# Processing Record 40 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vaini'
# Processing Record 41 of Set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Luderitz'
# Processing Record 42 of Set 1 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Deputatskiy'
# Processing Record 43 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Airai'
# Processing Record 44 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Klaksvik'
# Processing Record 45 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?q=salalah&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Salalah'
# Processing Record 46 of Set 1 | caconda
# http://api.openweathermap.org/data/2.5/weather?q=caconda&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Caconda'
# Processing Record 47 of Set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port%20hardy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Port Hardy'
# Processing Record 48 of Set 1 | nuqui
# http://api.openweathermap.org/data/2.5/weather?q=nuqui&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Nuqui'
# Processing Record 49 of Set 1 | bluefields
# http://api.openweathermap.org/data/2.5/weather?q=bluefields&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bluefields'
# Processing Record 50 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira%20grande&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ribeira Grande'
# Processing Record 1 of Set 2 | oistins
# http://api.openweathermap.org/data/2.5/weather?q=oistins&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Oistins'
# Processing Record 2 of Set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ancud'
# Processing Record 3 of Set 2 | quimper
# http://api.openweathermap.org/data/2.5/weather?q=quimper&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Quimper'
# Processing Record 4 of Set 2 | yarensk
# http://api.openweathermap.org/data/2.5/weather?q=yarensk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yarensk'
# Processing Record 5 of Set 2 | potsdam
# http://api.openweathermap.org/data/2.5/weather?q=potsdam&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Potsdam'
# Processing Record 6 of Set 2 | shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?q=shubarkuduk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Shubarkuduk'
# Processing Record 7 of Set 2 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Nhulunbuy'
# Processing Record 8 of Set 2 | rudnogorsk
# http://api.openweathermap.org/data/2.5/weather?q=rudnogorsk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Rudnogorsk'
# Processing Record 9 of Set 2 | chagda
# http://api.openweathermap.org/data/2.5/weather?q=chagda&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 10 of Set 2 | tongren
# http://api.openweathermap.org/data/2.5/weather?q=tongren&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tongren'
# Processing Record 11 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tiksi'
# Processing Record 12 of Set 2 | staden
# http://api.openweathermap.org/data/2.5/weather?q=staden&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Staden'
# Processing Record 13 of Set 2 | irtyshskiy
# http://api.openweathermap.org/data/2.5/weather?q=irtyshskiy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Irtyshskiy'
# Processing Record 14 of Set 2 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?q=sao%20jose%20da%20coroa%20grande&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sao Jose da Coroa Grande'
# Processing Record 15 of Set 2 | huilong
# http://api.openweathermap.org/data/2.5/weather?q=huilong&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Huilong'
# Processing Record 16 of Set 2 | inhambane
# http://api.openweathermap.org/data/2.5/weather?q=inhambane&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Inhambane'
# Processing Record 17 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 18 of Set 2 | myaundzha
# http://api.openweathermap.org/data/2.5/weather?q=myaundzha&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Myaundzha'
# Processing Record 19 of Set 2 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?q=muravlenko&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Muravlenko'
# Processing Record 20 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 21 of Set 2 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand%20river%20south%20east&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 22 of Set 2 | parrita
# http://api.openweathermap.org/data/2.5/weather?q=parrita&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Parrita'
# Processing Record 23 of Set 2 | sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sorland'
# Processing Record 24 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pevek'
# Processing Record 25 of Set 2 | wewak
# http://api.openweathermap.org/data/2.5/weather?q=wewak&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Wewak'
# Processing Record 26 of Set 2 | samarai
# http://api.openweathermap.org/data/2.5/weather?q=samarai&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Samarai'
# Processing Record 27 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Severo-Kurilsk'
# Processing Record 28 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yellowknife'
# Processing Record 29 of Set 2 | richards bay
# http://api.openweathermap.org/data/2.5/weather?q=richards%20bay&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Richards Bay'
# Processing Record 30 of Set 2 | margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Margate'
# Processing Record 31 of Set 2 | henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties%20bay&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Henties Bay'
# Processing Record 32 of Set 2 | atambua
# http://api.openweathermap.org/data/2.5/weather?q=atambua&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Atambua'
# Processing Record 33 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Qaanaaq'
# Processing Record 34 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bredasdorp'
# Processing Record 35 of Set 2 | kangaba
# http://api.openweathermap.org/data/2.5/weather?q=kangaba&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kangaba'
# Processing Record 36 of Set 2 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?q=ponta%20delgada&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ponta Delgada'
# Processing Record 37 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hermanus'
# Processing Record 38 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Victoria'
# Processing Record 39 of Set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 40 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bethel'
# Processing Record 41 of Set 2 | isangel
# http://api.openweathermap.org/data/2.5/weather?q=isangel&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Isangel'
# Processing Record 42 of Set 2 | karauzyak
# http://api.openweathermap.org/data/2.5/weather?q=karauzyak&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 43 of Set 2 | jinchang
# http://api.openweathermap.org/data/2.5/weather?q=jinchang&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Jinchang'
# Processing Record 44 of Set 2 | middelburg
# http://api.openweathermap.org/data/2.5/weather?q=middelburg&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Middelburg'
# Processing Record 45 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kapaa'
# Processing Record 46 of Set 2 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yar-Sale'
# Processing Record 47 of Set 2 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?q=derzhavinsk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Derzhavinsk'
# Processing Record 48 of Set 2 | seymour
# http://api.openweathermap.org/data/2.5/weather?q=seymour&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Seymour'
# Processing Record 49 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cidreira'
# Processing Record 50 of Set 2 | vanavara
# http://api.openweathermap.org/data/2.5/weather?q=vanavara&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vanavara'
# Processing Record 1 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial%20do%20cabo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Arraial do Cabo'
# Processing Record 2 of Set 3 | sfantu gheorghe
# http://api.openweathermap.org/data/2.5/weather?q=sfantu%20gheorghe&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sfantu Gheorghe'
# Processing Record 3 of Set 3 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?q=santa%20rosa&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Santa Rosa'
# Processing Record 4 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman%20wells&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Norman Wells'
# Processing Record 5 of Set 3 | rockland
# http://api.openweathermap.org/data/2.5/weather?q=rockland&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Rockland'
# Processing Record 6 of Set 3 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta%20do%20sol&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ponta do Sol'
# Processing Record 7 of Set 3 | torres
# http://api.openweathermap.org/data/2.5/weather?q=torres&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Torres'
# Processing Record 8 of Set 3 | alamor
# http://api.openweathermap.org/data/2.5/weather?q=alamor&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Alamor'
# Processing Record 9 of Set 3 | vigrestad
# http://api.openweathermap.org/data/2.5/weather?q=vigrestad&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vigrestad'
# Processing Record 10 of Set 3 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Torbay'
# Processing Record 11 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Longyearbyen'
# Processing Record 12 of Set 3 | barabai
# http://api.openweathermap.org/data/2.5/weather?q=barabai&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Barabai'
# Processing Record 13 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sitka'
# Processing Record 14 of Set 3 | santo augusto
# http://api.openweathermap.org/data/2.5/weather?q=santo%20augusto&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Santo Augusto'
# Processing Record 15 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Upernavik'
# Processing Record 16 of Set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Geraldton'
# Processing Record 17 of Set 3 | dali
# http://api.openweathermap.org/data/2.5/weather?q=dali&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dali'
# Processing Record 18 of Set 3 | bonthe
# http://api.openweathermap.org/data/2.5/weather?q=bonthe&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bonthe'
# Processing Record 19 of Set 3 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Saint-Pierre'
# Processing Record 20 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Esperance'
# Processing Record 21 of Set 3 | san rafael
# http://api.openweathermap.org/data/2.5/weather?q=san%20rafael&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'San Rafael'
# Processing Record 22 of Set 3 | muros
# http://api.openweathermap.org/data/2.5/weather?q=muros&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Muros'
# Processing Record 23 of Set 3 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap%20malheureux&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cap Malheureux'
# Processing Record 24 of Set 3 | thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Thompson'
# Processing Record 25 of Set 3 | yumen
# http://api.openweathermap.org/data/2.5/weather?q=yumen&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yumen'
# Processing Record 26 of Set 3 | rexburg
# http://api.openweathermap.org/data/2.5/weather?q=rexburg&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Rexburg'
# Processing Record 27 of Set 3 | bloemfontein
# http://api.openweathermap.org/data/2.5/weather?q=bloemfontein&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bloemfontein'
# Processing Record 28 of Set 3 | yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?q=yerofey%20pavlovich&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yerofey Pavlovich'
# Processing Record 29 of Set 3 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?q=preobrazheniye&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Preobrazheniye'
# Processing Record 30 of Set 3 | rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Rocha'
# Processing Record 31 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Khatanga'
# Processing Record 32 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Talnakh'
# Processing Record 33 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cherskiy'
# Processing Record 34 of Set 3 | seydi
# http://api.openweathermap.org/data/2.5/weather?q=seydi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Seydi'
# Processing Record 35 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo%20san%20lucas&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cabo San Lucas'
# Processing Record 36 of Set 3 | venado tuerto
# http://api.openweathermap.org/data/2.5/weather?q=venado%20tuerto&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Venado Tuerto'
# Processing Record 37 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Chokurdakh'
# Processing Record 38 of Set 3 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?q=pacific%20grove&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pacific Grove'
# Processing Record 39 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kodiak'
# Processing Record 40 of Set 3 | cervo
# http://api.openweathermap.org/data/2.5/weather?q=cervo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cervo'
# Processing Record 41 of Set 3 | nishihara
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Nishihara'
# Processing Record 42 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Souillac'
# Processing Record 43 of Set 3 | masvingo
# http://api.openweathermap.org/data/2.5/weather?q=masvingo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Masvingo'
# Processing Record 44 of Set 3 | yakeshi
# http://api.openweathermap.org/data/2.5/weather?q=yakeshi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yakeshi'
# Processing Record 45 of Set 3 | caravelas
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Caravelas'
# Processing Record 46 of Set 3 | karasuk
# http://api.openweathermap.org/data/2.5/weather?q=karasuk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Karasuk'
# Processing Record 47 of Set 3 | north bend
# http://api.openweathermap.org/data/2.5/weather?q=north%20bend&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'North Bend'
# Processing Record 48 of Set 3 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yerbogachen'
# Processing Record 49 of Set 3 | kananga
# http://api.openweathermap.org/data/2.5/weather?q=kananga&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kananga'
# Processing Record 50 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Faanui'
# Processing Record 1 of Set 4 | adrar
# http://api.openweathermap.org/data/2.5/weather?q=adrar&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Adrar'
# Processing Record 2 of Set 4 | linxia
# http://api.openweathermap.org/data/2.5/weather?q=linxia&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Linxia'
# Processing Record 3 of Set 4 | muli
# http://api.openweathermap.org/data/2.5/weather?q=muli&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Muli'
# Processing Record 4 of Set 4 | hwange
# http://api.openweathermap.org/data/2.5/weather?q=hwange&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hwange'
# Processing Record 5 of Set 4 | itoman
# http://api.openweathermap.org/data/2.5/weather?q=itoman&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Itoman'
# Processing Record 6 of Set 4 | tura
# http://api.openweathermap.org/data/2.5/weather?q=tura&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tura'
# Processing Record 7 of Set 4 | los andes
# http://api.openweathermap.org/data/2.5/weather?q=los%20andes&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Los Andes'
# Processing Record 8 of Set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?q=berlevag&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Berlevag'
# Processing Record 9 of Set 4 | belmonte
# http://api.openweathermap.org/data/2.5/weather?q=belmonte&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Belmonte'
# Processing Record 10 of Set 4 | alexandria
# http://api.openweathermap.org/data/2.5/weather?q=alexandria&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Alexandria'
# Processing Record 11 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Padang'
# Processing Record 12 of Set 4 | dumabato
# http://api.openweathermap.org/data/2.5/weather?q=dumabato&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dumabato'
# Processing Record 13 of Set 4 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?q=lufilufi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lufilufi'
# Processing Record 14 of Set 4 | maceio
# http://api.openweathermap.org/data/2.5/weather?q=maceio&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Maceio'
# Processing Record 15 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?q=lata&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lata'
# Processing Record 16 of Set 4 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?q=cockburn%20town&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cockburn Town'
# Processing Record 17 of Set 4 | cabinda
# http://api.openweathermap.org/data/2.5/weather?q=cabinda&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cabinda'
# Processing Record 18 of Set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pangnirtung'
# Processing Record 19 of Set 4 | malwan
# http://api.openweathermap.org/data/2.5/weather?q=malwan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 20 of Set 4 | havelock
# http://api.openweathermap.org/data/2.5/weather?q=havelock&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Havelock'
# Processing Record 21 of Set 4 | el alto
# http://api.openweathermap.org/data/2.5/weather?q=el%20alto&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'El Alto'
# Processing Record 22 of Set 4 | champerico
# http://api.openweathermap.org/data/2.5/weather?q=champerico&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Champerico'
# Processing Record 23 of Set 4 | dunedin
# http://api.openweathermap.org/data/2.5/weather?q=dunedin&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dunedin'
# Processing Record 24 of Set 4 | zirandaro
# http://api.openweathermap.org/data/2.5/weather?q=zirandaro&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Zirandaro'
# Processing Record 25 of Set 4 | terenos
# http://api.openweathermap.org/data/2.5/weather?q=terenos&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Terenos'
# Processing Record 26 of Set 4 | tahta
# http://api.openweathermap.org/data/2.5/weather?q=tahta&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 27 of Set 4 | arman
# http://api.openweathermap.org/data/2.5/weather?q=arman&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Arman'
# Processing Record 28 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Codrington'
# Processing Record 29 of Set 4 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Coquimbo'
# Processing Record 30 of Set 4 | aginskoye
# http://api.openweathermap.org/data/2.5/weather?q=aginskoye&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Aginskoye'
# Processing Record 31 of Set 4 | ulundi
# http://api.openweathermap.org/data/2.5/weather?q=ulundi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ulundi'
# Processing Record 32 of Set 4 | nichinan
# http://api.openweathermap.org/data/2.5/weather?q=nichinan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Nichinan'
# Processing Record 33 of Set 4 | kuusamo
# http://api.openweathermap.org/data/2.5/weather?q=kuusamo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kuusamo'
# Processing Record 34 of Set 4 | calgary
# http://api.openweathermap.org/data/2.5/weather?q=calgary&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Calgary'
# Processing Record 35 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde%20river&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Clyde River'
# Processing Record 36 of Set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lompoc'
# Processing Record 37 of Set 4 | general roca
# http://api.openweathermap.org/data/2.5/weather?q=general%20roca&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'General Roca'
# Processing Record 38 of Set 4 | marfino
# http://api.openweathermap.org/data/2.5/weather?q=marfino&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Marfino'
# Processing Record 39 of Set 4 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?q=umm%20lajj&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Umm Lajj'
# Processing Record 40 of Set 4 | batagay
# http://api.openweathermap.org/data/2.5/weather?q=batagay&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Batagay'
# Processing Record 41 of Set 4 | senneterre
# http://api.openweathermap.org/data/2.5/weather?q=senneterre&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Senneterre'
# Processing Record 42 of Set 4 | puerto castilla
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20castilla&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Puerto Castilla'
# Processing Record 43 of Set 4 | muzquiz
# http://api.openweathermap.org/data/2.5/weather?q=muzquiz&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 44 of Set 4 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 45 of Set 4 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?q=umzimvubu&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 46 of Set 4 | santa eulalia del rio
# http://api.openweathermap.org/data/2.5/weather?q=santa%20eulalia%20del%20rio&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 47 of Set 4 | kormilovka
# http://api.openweathermap.org/data/2.5/weather?q=kormilovka&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kormilovka'
# Processing Record 48 of Set 4 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount%20gambier&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mount Gambier'
# Processing Record 49 of Set 4 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?q=ulladulla&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ulladulla'
# Processing Record 50 of Set 4 | sola
# http://api.openweathermap.org/data/2.5/weather?q=sola&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sola'
# Processing Record 1 of Set 5 | sabzevar
# http://api.openweathermap.org/data/2.5/weather?q=sabzevar&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sabzevar'
# Processing Record 2 of Set 5 | port blair
# http://api.openweathermap.org/data/2.5/weather?q=port%20blair&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Port Blair'
# Processing Record 3 of Set 5 | vyshestebliyevskaya
# http://api.openweathermap.org/data/2.5/weather?q=vyshestebliyevskaya&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vyshestebliyevskaya'
# Processing Record 4 of Set 5 | akyab
# http://api.openweathermap.org/data/2.5/weather?q=akyab&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 5 of Set 5 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 6 of Set 5 | syracuse
# http://api.openweathermap.org/data/2.5/weather?q=syracuse&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Syracuse'
# Processing Record 7 of Set 5 | juba
# http://api.openweathermap.org/data/2.5/weather?q=juba&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Juba'
# Processing Record 8 of Set 5 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?q=sobolevo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sobolevo'
# Processing Record 9 of Set 5 | praya
# http://api.openweathermap.org/data/2.5/weather?q=praya&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Praya'
# Processing Record 10 of Set 5 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?q=mandalgovi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mandalgovi'
# Processing Record 11 of Set 5 | nizwa
# http://api.openweathermap.org/data/2.5/weather?q=nizwa&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Nizwa'
# Processing Record 12 of Set 5 | khash
# http://api.openweathermap.org/data/2.5/weather?q=khash&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Khash'
# Processing Record 13 of Set 5 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?q=makakilo%20city&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Makakilo City'
# Processing Record 14 of Set 5 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?q=marrakesh&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Marrakesh'
# Processing Record 15 of Set 5 | marcona
# http://api.openweathermap.org/data/2.5/weather?q=marcona&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 16 of Set 5 | mergui
# http://api.openweathermap.org/data/2.5/weather?q=mergui&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 17 of Set 5 | magway
# http://api.openweathermap.org/data/2.5/weather?q=magway&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Magway'
# Processing Record 18 of Set 5 | baturaja
# http://api.openweathermap.org/data/2.5/weather?q=baturaja&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Baturaja'
# Processing Record 19 of Set 5 | storforshei
# http://api.openweathermap.org/data/2.5/weather?q=storforshei&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Storforshei'
# Processing Record 20 of Set 5 | biak
# http://api.openweathermap.org/data/2.5/weather?q=biak&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Biak'
# Processing Record 21 of Set 5 | khorion
# http://api.openweathermap.org/data/2.5/weather?q=khorion&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 22 of Set 5 | flinders
# http://api.openweathermap.org/data/2.5/weather?q=flinders&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Flinders'
# Processing Record 23 of Set 5 | samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 24 of Set 5 | yulara
# http://api.openweathermap.org/data/2.5/weather?q=yulara&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yulara'
# Processing Record 25 of Set 5 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vestmannaeyjar'
# Processing Record 26 of Set 5 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?q=tsiroanomandidy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tsiroanomandidy'
# Processing Record 27 of Set 5 | punto fijo
# http://api.openweathermap.org/data/2.5/weather?q=punto%20fijo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Punto Fijo'
# Processing Record 28 of Set 5 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?q=svetlaya&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Svetlaya'
# Processing Record 29 of Set 5 | mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mehamn'
# Processing Record 30 of Set 5 | kamina
# http://api.openweathermap.org/data/2.5/weather?q=kamina&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kamina'
# Processing Record 31 of Set 5 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero%20negro&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Guerrero Negro'
# Processing Record 32 of Set 5 | kirakira
# http://api.openweathermap.org/data/2.5/weather?q=kirakira&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kirakira'
# Processing Record 33 of Set 5 | chiredzi
# http://api.openweathermap.org/data/2.5/weather?q=chiredzi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Chiredzi'
# Processing Record 34 of Set 5 | botshabelo
# http://api.openweathermap.org/data/2.5/weather?q=botshabelo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Botshabelo'
# Processing Record 35 of Set 5 | dakar
# http://api.openweathermap.org/data/2.5/weather?q=dakar&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dakar'
# Processing Record 36 of Set 5 | elko
# http://api.openweathermap.org/data/2.5/weather?q=elko&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Elko'
# Processing Record 37 of Set 5 | aguimes
# ...
# http://api.openweathermap.org/data/2.5/weather?q=sao%20joao%20da%20barra&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sao Joao da Barra'
# Processing Record 6 of Set 10 | fare
# http://api.openweathermap.org/data/2.5/weather?q=fare&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Fare'
# Processing Record 7 of Set 10 | hualmay
# http://api.openweathermap.org/data/2.5/weather?q=hualmay&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hualmay'
# Processing Record 8 of Set 10 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Jacareacanga'
# Processing Record 9 of Set 10 | aksaray
# http://api.openweathermap.org/data/2.5/weather?q=aksaray&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Aksaray'
# Processing Record 10 of Set 10 | darnah
# http://api.openweathermap.org/data/2.5/weather?q=darnah&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Darnah'
# Processing Record 11 of Set 10 | abha
# http://api.openweathermap.org/data/2.5/weather?q=abha&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Abha'
# Processing Record 12 of Set 10 | yinchuan
# http://api.openweathermap.org/data/2.5/weather?q=yinchuan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Yinchuan'
# Processing Record 13 of Set 10 | avera
# http://api.openweathermap.org/data/2.5/weather?q=avera&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Avera'
# Processing Record 14 of Set 10 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?q=vangaindrano&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vangaindrano'
# Processing Record 15 of Set 10 | vitim
# http://api.openweathermap.org/data/2.5/weather?q=vitim&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Vitim'
# Processing Record 16 of Set 10 | tual
# http://api.openweathermap.org/data/2.5/weather?q=tual&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tual'
# Processing Record 17 of Set 10 | sabang
# http://api.openweathermap.org/data/2.5/weather?q=sabang&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sabang'
# Processing Record 18 of Set 10 | lugazi
# http://api.openweathermap.org/data/2.5/weather?q=lugazi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lugazi'
# Processing Record 19 of Set 10 | shimoda
# http://api.openweathermap.org/data/2.5/weather?q=shimoda&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Shimoda'
# Processing Record 20 of Set 10 | sheridan
# http://api.openweathermap.org/data/2.5/weather?q=sheridan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sheridan'
# Processing Record 21 of Set 10 | villa maria
# http://api.openweathermap.org/data/2.5/weather?q=villa%20maria&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Villa Maria'
# Processing Record 22 of Set 10 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Taoudenni'
# Processing Record 23 of Set 10 | mweka
# http://api.openweathermap.org/data/2.5/weather?q=mweka&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mweka'
# Processing Record 24 of Set 10 | mouila
# http://api.openweathermap.org/data/2.5/weather?q=mouila&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mouila'
# Processing Record 25 of Set 10 | pandan
# http://api.openweathermap.org/data/2.5/weather?q=pandan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pandan'
# Processing Record 26 of Set 10 | anadyr
# http://api.openweathermap.org/data/2.5/weather?q=anadyr&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Anadyr'
# Processing Record 27 of Set 10 | volokolamsk
# http://api.openweathermap.org/data/2.5/weather?q=volokolamsk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Volokolamsk'
# Processing Record 28 of Set 10 | ternate
# http://api.openweathermap.org/data/2.5/weather?q=ternate&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ternate'
# Processing Record 29 of Set 10 | huanren
# http://api.openweathermap.org/data/2.5/weather?q=huanren&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Huanren'
# Processing Record 30 of Set 10 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?q=poronaysk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Poronaysk'
# Processing Record 31 of Set 10 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bathsheba'
# Processing Record 32 of Set 10 | pesaro
# http://api.openweathermap.org/data/2.5/weather?q=pesaro&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pesaro'
# Processing Record 33 of Set 10 | aranda de duero
# http://api.openweathermap.org/data/2.5/weather?q=aranda%20de%20duero&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Aranda de Duero'
# Processing Record 34 of Set 10 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Komsomolskiy'
# Processing Record 35 of Set 10 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Leningradskiy'
# Processing Record 36 of Set 10 | sigli
# http://api.openweathermap.org/data/2.5/weather?q=sigli&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sigli'
# Processing Record 37 of Set 10 | dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dingle'
# Processing Record 38 of Set 10 | paradwip
# http://api.openweathermap.org/data/2.5/weather?q=paradwip&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 39 of Set 10 | panzhihua
# http://api.openweathermap.org/data/2.5/weather?q=panzhihua&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Panzhihua'
# Processing Record 40 of Set 10 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ixtapa'
# Processing Record 41 of Set 10 | tolbazy
# http://api.openweathermap.org/data/2.5/weather?q=tolbazy&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tolbazy'
# Processing Record 42 of Set 10 | arlit
# http://api.openweathermap.org/data/2.5/weather?q=arlit&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Arlit'
# Processing Record 43 of Set 10 | alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Alofi'
# Processing Record 44 of Set 10 | tongchuan
# http://api.openweathermap.org/data/2.5/weather?q=tongchuan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Tongchuan'
# Processing Record 45 of Set 10 | dubai
# http://api.openweathermap.org/data/2.5/weather?q=dubai&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Dubai'
# Processing Record 46 of Set 10 | cuamba
# http://api.openweathermap.org/data/2.5/weather?q=cuamba&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Cuamba'
# Processing Record 47 of Set 10 | kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kahului'
# Processing Record 48 of Set 10 | fallon
# http://api.openweathermap.org/data/2.5/weather?q=fallon&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Fallon'
# Processing Record 49 of Set 10 | sechura
# http://api.openweathermap.org/data/2.5/weather?q=sechura&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sechura'
# Processing Record 50 of Set 10 | mosquera
# http://api.openweathermap.org/data/2.5/weather?q=mosquera&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mosquera'
# Processing Record 1 of Set 11 | kingori
# http://api.openweathermap.org/data/2.5/weather?q=kingori&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kingori'
# Processing Record 2 of Set 11 | lulea
# http://api.openweathermap.org/data/2.5/weather?q=lulea&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lulea'
# Processing Record 3 of Set 11 | kupang
# http://api.openweathermap.org/data/2.5/weather?q=kupang&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kupang'
# Processing Record 4 of Set 11 | iquique
# http://api.openweathermap.org/data/2.5/weather?q=iquique&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Iquique'
# Processing Record 5 of Set 11 | balimo
# http://api.openweathermap.org/data/2.5/weather?q=balimo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 6 of Set 11 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?q=victor%20harbor&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Victor Harbor'
# Processing Record 7 of Set 11 | luganville
# http://api.openweathermap.org/data/2.5/weather?q=luganville&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Luganville'
# Processing Record 8 of Set 11 | coolum beach
# http://api.openweathermap.org/data/2.5/weather?q=coolum%20beach&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Coolum Beach'
# Processing Record 9 of Set 11 | namatanai
# http://api.openweathermap.org/data/2.5/weather?q=namatanai&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Namatanai'
# Processing Record 10 of Set 11 | sogdiondon
# http://api.openweathermap.org/data/2.5/weather?q=sogdiondon&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 11 of Set 11 | diamantino
# http://api.openweathermap.org/data/2.5/weather?q=diamantino&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Diamantino'
# Processing Record 12 of Set 11 | toritama
# http://api.openweathermap.org/data/2.5/weather?q=toritama&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Toritama'
# Processing Record 13 of Set 11 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sept-Iles'
# Processing Record 14 of Set 11 | yirol
# http://api.openweathermap.org/data/2.5/weather?q=yirol&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 15 of Set 11 | zonguldak
# http://api.openweathermap.org/data/2.5/weather?q=zonguldak&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Zonguldak'
# Processing Record 16 of Set 11 | yambio
# http://api.openweathermap.org/data/2.5/weather?q=yambio&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 17 of Set 11 | serenje
# http://api.openweathermap.org/data/2.5/weather?q=serenje&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Serenje'
# Processing Record 18 of Set 11 | altamont
# http://api.openweathermap.org/data/2.5/weather?q=altamont&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Altamont'
# Processing Record 19 of Set 11 | manokwari
# http://api.openweathermap.org/data/2.5/weather?q=manokwari&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Manokwari'
# Processing Record 20 of Set 11 | navoi
# http://api.openweathermap.org/data/2.5/weather?q=navoi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Navoi'
# Processing Record 21 of Set 11 | sedelnikovo
# http://api.openweathermap.org/data/2.5/weather?q=sedelnikovo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 22 of Set 11 | gibara
# http://api.openweathermap.org/data/2.5/weather?q=gibara&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Gibara'
# Processing Record 23 of Set 11 | hamilton
# http://api.openweathermap.org/data/2.5/weather?q=hamilton&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Hamilton'
# Processing Record 24 of Set 11 | salme
# http://api.openweathermap.org/data/2.5/weather?q=salme&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Salme'
# Processing Record 25 of Set 11 | bacuit
# http://api.openweathermap.org/data/2.5/weather?q=bacuit&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 26 of Set 11 | ust-ilimsk
# http://api.openweathermap.org/data/2.5/weather?q=ust-ilimsk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ust-Ilimsk'
# Processing Record 27 of Set 11 | mazabuka
# http://api.openweathermap.org/data/2.5/weather?q=mazabuka&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Mazabuka'
# Processing Record 28 of Set 11 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?q=abu%20samrah&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Abu Samrah'
# Processing Record 29 of Set 11 | pahrump
# http://api.openweathermap.org/data/2.5/weather?q=pahrump&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Pahrump'
# Processing Record 30 of Set 11 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?q=ugoofaaru&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Ugoofaaru'
# Processing Record 31 of Set 11 | voznesenye
# http://api.openweathermap.org/data/2.5/weather?q=voznesenye&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Voznesenye'
# Processing Record 32 of Set 11 | xining
# http://api.openweathermap.org/data/2.5/weather?q=xining&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Xining'
# Processing Record 33 of Set 11 | clearwater
# http://api.openweathermap.org/data/2.5/weather?q=clearwater&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Clearwater'
# Processing Record 34 of Set 11 | easton
# http://api.openweathermap.org/data/2.5/weather?q=easton&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Easton'
# Processing Record 35 of Set 11 | sorvag
# http://api.openweathermap.org/data/2.5/weather?q=sorvag&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 36 of Set 11 | port keats
# http://api.openweathermap.org/data/2.5/weather?q=port%20keats&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Port Keats'
# Processing Record 37 of Set 11 | lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Lagoa'
# Processing Record 38 of Set 11 | kurumkan
# http://api.openweathermap.org/data/2.5/weather?q=kurumkan&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kurumkan'
# Processing Record 39 of Set 11 | turtas
# http://api.openweathermap.org/data/2.5/weather?q=turtas&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Turtas'
# Processing Record 40 of Set 11 | othonoi
# http://api.openweathermap.org/data/2.5/weather?q=othonoi&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# HTTP Error 404: Not Found
# Processing Record 41 of Set 11 | osoyoos
# http://api.openweathermap.org/data/2.5/weather?q=osoyoos&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Osoyoos'
# Processing Record 42 of Set 11 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san%20cristobal&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'San Cristobal'
# Processing Record 43 of Set 11 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Zhigansk'
# Processing Record 44 of Set 11 | panaba
# http://api.openweathermap.org/data/2.5/weather?q=panaba&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Panaba'
# Processing Record 45 of Set 11 | sibu
# http://api.openweathermap.org/data/2.5/weather?q=sibu&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sibu'
# Processing Record 46 of Set 11 | bogo
# http://api.openweathermap.org/data/2.5/weather?q=bogo&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Bogo'
# Processing Record 47 of Set 11 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Sinnamary'
# Processing Record 48 of Set 11 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Kavaratti'
# Processing Record 49 of Set 11 | constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Constitucion'
# Processing Record 50 of Set 11 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?q=santiago%20del%20estero&units=imperial&APPID=ca948e37c7fc34fc07a1ece6ffdb31a0
# 'Santiago del Estero'
# end of stats loop
# Could not get data for 600 cities

# %%
WeatherPy_df.count()
# Out:
# City          0
# Cloudiness    0
# Country       0
# Date          0
# Max Temp      0
# Wind Speed    0
# Lat           0
# Lng           0
# Humidity      0
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
count = 0
#error = 0
sets = 0
index = 0

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
